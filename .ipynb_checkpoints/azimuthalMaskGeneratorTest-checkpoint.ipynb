# %%
import numpy as np
import fabio
import matplotlib.pyplot as plt
import pyFAI
import pyFAI.geometry
import os

# %%
file = r'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap\Si\xrd\maps\pyfai/Si_700_dty_179_2thmap.edf'
datafile = r'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap\glass2\pos1/glass_700_dty_179_000_0008p.cbf'
array = fabio.open(file).data
dataarray = fabio.open(datafile).data
plt.figure()
plt.imshow(array)
plt.figure()
plt.imshow(dataarray)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
# %matplotlib inline
hist = np.histogram(array,bins = 500)
plt.bar(hist[1][1:],hist[0],width = 0.02)
# Out:
# <BarContainer object of 500 artists>

# %%
bins = 1000
binsize = np.max(array)/bins
binarray = (array/binsize).astype(np.uint16)
binarray = np.where(dataarray < 0, -1, binarray)

# %%
# %matplotlib nbagg
plt.imshow(binarray)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
plt.figure()
plt.imshow(np.where(binarray == 100, dataarray,0))
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
plt.figure()
plt.imshow(binarray)

# %%
mask = fabio.open(r'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap/minMask.edf').data

for n in range(bins):
    array = np.where(binarray == n, dataarray, np.nan)
    stdev = np.nanstd(array)
    median = np.nanmedian(array)
    mask = np.where(array > median + 3*stdev, 1, mask)

# %%
plt.figure()
plt.imshow(mask)
plt.figure()
plt.imshow(dataarray)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# <img src="data:image/png;base64,..." width="640.0000169542105">
