# %%
import pyFAI
import fabio
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import os, re
def gainCorrection(avim,gainArray):
    avimGain = avim/gainArray
    avimGain = np.where(gainArray <0, -1, avimGain)
    return avimGain
def clearPyFAI_header(file):
    x,y,e = np.loadtxt(file,unpack = True, comments = '#')
    np.savetxt(file,np.array([x,y,e]).transpose(), '%.6f')

# %%
# %matplotlib nbagg



direc = r'C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd/' # Directory of xrd files

ponis = glob(r'C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap/*.poni')


pos = re.split('/|\\\\',direc)[-3]
poni = [poni for poni in ponis if pos == os.path.basename(poni).split('_')[0]][0]
print(poni)
os.chdir(direc)
dest = direc #fr'C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure/{pos}/xrd/'
if not os.path.exists(dest):
    os.makedirs(dest)

mask  = fr'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap\minMask.edf' # Mask file
mask = fabio.open(mask).data

poni = pyFAI.load(poni)

gainFile = r'C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap/calculatedGainMap_48p6keV_filtered_kpm_2023-04-11.edf'
#gainFile = r'C:\Users\kenneth1a\Documents\maskGenerator/calculatedGainMap_48p6keV_kpm_filtered.edf'
gainArray = fabio.open(gainFile).data


files = glob('*.cbf')
i1 = fabio.open(files[0]).data
dataset = np.empty(shape = (*i1.shape,len(files)))

doMonitor = True

#monitorfile = glob('*.dat')[0]
#monitor = np.loadtxt(monitorfile,usecols = 2, skiprows = 1)

scale = 10**9
for c,file in enumerate(files):

    array = fabio.open(file).data
    if doMonitor:
        #array = (array/monitor[c])*scale
        fileheader = fabio.open(file).header["_array_data.header_contents"].split('\r\n#')
        monitor = int([item for item in fileheader if 'Flux' in item][0].replace('Flux',''))
        array = (array/monitor)*scale
    dataset[:,:,c] = array
    
    vmax = np.percentile(np.where(np.isnan(array),0,array),99.9)
    #plt.figure()
    #plt.imshow(array,vmax = vmax)
    #plt.colorbar()
average = np.average(dataset,axis=2)
median = np.median(dataset,axis=2)
vmax = np.percentile(np.where(np.isnan(average),0,average),99.9)
plt.figure()
plt.imshow(average,vmax = vmax)
plt.colorbar()
# Out:
# C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\pos7_y_222_z_53p5.poni
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
plt.figure()
stdev = np.std(dataset,axis = 2)
vmax = np.percentile(np.where(np.isnan(stdev),0,stdev),99.9)
plt.imshow(np.std(dataset,axis = 2),vmax = vmax)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# %matplotlib inline
maskdct = {}
nstdevs = 3
for c in range(len(files)):
    print(files[c])
    array = dataset[:,:,c]
    vmax = np.percentile(np.where(np.isnan(array),0,array),99.5)
    maskdct[c] = np.where(array > median+nstdevs*stdev,1,mask)
    #fig,ax = plt.subplots(1,2,dpi = 150)
    #ax[0].imshow(maskdct[c])
    #ax[1].imshow(array,vmax = vmax)
    #plt.show()
# Out:
# measuringCylinder_dty_222_dtz_53p5_000_0001p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0002p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0003p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0004p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0005p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0006p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0007p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0008p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0009p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0010p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0011p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0012p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0013p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0014p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0015p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0016p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0017p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0018p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0019p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0020p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0021p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0022p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0023p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0024p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0025p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0026p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0027p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0028p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0029p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0030p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0031p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0032p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0033p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0034p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0035p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0036p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0037p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0038p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0039p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0040p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0041p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0042p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0043p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0044p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0045p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0046p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0047p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0048p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0049p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0050p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0051p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0052p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0053p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0054p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0055p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0056p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0057p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0058p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0059p.cbf
# measuringCylinder_dty_222_dtz_53p5_000_0060p.cbf

# %%
subdir = f'xye_{nstdevs}stdevs/'
clearHeader = True

if not os.path.exists(f'{dest}/average/xye/'):
    os.makedirs(f'{dest}/average/xye/')

#if not os.path.exists(f'{dest}/monNormImages/'):
#    os.makedirs(f'{dest}/monNormImages/')
dataset2 = np.empty(shape = dataset.shape)

for n in maskdct:
    #print(files[n])
    dataset2[:,:,n] = np.where(maskdct[n] == 0, dataset[:,:,n], np.nan)
    #array = np.where(maskdct[n] == 0, dataset[:,:,n], -2)
    #image = fabio.cbfimage.CbfImage(array)
    #image.save(f'{dest}/monNormImages/{files[n]}')
 
avim = np.nanmean(dataset2, axis = 2)
avim = np.where(np.isnan(avim), -2, avim)
im = fabio.cbfimage.CbfImage(avim)
im.save(f'{dest}/average/average.cbf')

avimGain = gainCorrection(avim,gainArray)
imGain = fabio.cbfimage.CbfImage(avimGain)
imGain.save(f'{dest}/average/average_gainCorrected.cbf')

mask_av = np.where(avim < 0, 1, 0)
mask_avGain = np.where(avimGain < 0, 1, 0)

outfile = f'{dest}/average/xye/average.xye'
poni.integrate1d(data = avim, filename = outfile,mask = mask_av,polarization_factor = 0.99,unit = '2th_deg',
                correctSolidAngle = True, method = 'bbox',npt = 5000, error_model = 'poisson', safe = False)
outfileGC = f'{dest}/average/xye/average_gainCorrected.xye'
poni.integrate1d(data = avimGain, filename = outfileGC,mask = mask_avGain,polarization_factor = 0.99,unit = '2th_deg',
                correctSolidAngle = True, method = 'bbox',npt = 5000, error_model = 'poisson', safe = False)
clearPyFAI_header(outfile)
clearPyFAI_header(outfileGC)
if not os.path.exists(f'{dest}/{subdir}/average/'):
    os.makedirs(f'{dest}/{subdir}/average/')

for c,file in enumerate(files):
    print(file)
    xyefile = file.replace('.cbf','.xye')
    outputfile = f'{dest}/{subdir}/{xyefile}'
    x,y,e = poni.integrate1d(data = dataset[:,:,c], filename = outputfile,mask = maskdct[c],polarization_factor = 0.99,unit = '2th_deg',
                    correctSolidAngle = True, method = 'bbox',npt = 5000, error_model = 'poisson',safe = False)
    
    outputfileGC = f'{dest}/{subdirGain}/{xyefile}'
    arrayGC = dataset[:,:,c]/gainArray
    arrayGC = np.where(gainArray < 0, -1, arrayGC)
    xg,yg,eg = poni.integrate1d(data = arrayGC, filename = outputfileGC,mask = maskdct[c],polarization_factor = 0.99,unit = '2th_deg',
                    correctSolidAngle = True, method = 'bbox',npt = 5000, error_model = 'poisson', safe = False)
    
    if clearHeader:
        clearPyFAI_header(outputfile)
        clearPyFAI_header(outputfileGC)
    if c == 0:
        av1d = np.empty(shape = (len(y),len(files)))
        eav = np.empty(shape = (len(y),len(files)))
    av1d[:,c] = y
    eav[:,c] = e
av1d = np.average(av1d,axis=1)
eav = np.average(eav,axis = 1)
np.savetxt(f'{dest}{subdir}average/{xyefile}',np.array([x,av1d,eav]).transpose())

qav = av1d*4*np.pi*np.sin(x*np.pi/(180*2))/0.25509
np.savetxt(f'{dest}{subdir}average/qav.xy',np.array([x,qav]).transpose())
# Out:
# C:\Users\kenneth1a\AppData\Local\Temp\ipykernel_16944\2546092373.py:18: RuntimeWarning: Mean of empty slice
#   avim = np.nanmean(dataset2, axis = 2)
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//average/xye/average.xye exists
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//average/xye/average_gainCorrected.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0001p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0001p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0002p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0002p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0003p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0003p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0004p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0004p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0005p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0005p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0006p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0006p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0007p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0007p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0008p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0008p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0009p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0009p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0010p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0010p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0011p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0011p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0012p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0012p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0013p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0013p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0014p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0014p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0015p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0015p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0016p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0016p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0017p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0017p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0018p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0018p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0019p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0019p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0020p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0020p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0021p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0021p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0022p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0022p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0023p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0023p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0024p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0024p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0025p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0025p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0026p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0026p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0027p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0027p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0028p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0028p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0029p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0029p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0030p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0030p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0031p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0031p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0032p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0032p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0033p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0033p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0034p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0034p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0035p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0035p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0036p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0036p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0037p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0037p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0038p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0038p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0039p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0039p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0040p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0040p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0041p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0041p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0042p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0042p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0043p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0043p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0044p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0044p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0045p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0045p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0046p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0046p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0047p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0047p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0048p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0048p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0049p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0049p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0050p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0050p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0051p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0051p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0052p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0052p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0053p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0053p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0054p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0054p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0055p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0055p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0056p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0056p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0057p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0057p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0058p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0058p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0059p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0059p.xye exists
# measuringCylinder_dty_222_dtz_53p5_000_0060p.cbf
# WARNING:pyFAI.io:Destination file C:\Users\kenneth1a\Documents\beamlineData\March2023_gainMap\GainMeasure\pos7/xrd//xye_3stdevs//measuringCylinder_dty_222_dtz_53p5_000_0060p.xye exists
