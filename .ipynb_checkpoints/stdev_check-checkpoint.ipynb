# %%
import pyFAI
import fabio
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import os, re

# %%
# %matplotlib inline

direc = r'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap\glass2/' # Directory of xrd files
os.chdir(direc)

dest = direc
if not os.path.exists(dest):
    os.makedirs(dest)

mask  = r'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap\minMask.edf' # Mask file
mask = fabio.open(mask).data
#poni  = r'C:\Users\kenneth1a\Documents\beamlineData\a311189_pdf\Si_0_15tilt.poni' # Poni file
#poni = pyFAI.load(poni)
gainFile = r'C:\Users\kenneth1a\Documents\maskGenerator/calculatedGainMap_48p6keV_kpm_filtered.edf'

gainArray = fabio.open(gainFile).data

allDataSets = {}
subdirs = ['pos1','pos2','pos3','pos4','pos5']
doMonitor = True

scale = 3.6e6

for s in subdirs:
    
    files = glob(f'{s}/*.cbf')
    i1 = fabio.open(files[0]).data
    dataset = np.empty(shape = (*i1.shape,len(files)))
    

    
    monitorfile = glob(f'{s}/*.dat')[0]
    print(monitorfile)
    monitor = np.loadtxt(monitorfile,usecols = 2, skiprows = 1)
    
    
    for c,file in enumerate(files):
        
        array = fabio.open(file).data
        if doMonitor:
            array = ((array/monitor[c])*scale).astype(np.float32)
        dataset[:,:,c] = array

    allDataSets[s] = dataset
    #average = np.average(dataset,axis=2)
    #median = np.median(dataset,axis=2)
    #vmax = np.percentile(np.where(np.isnan(average),0,average),99.9)
    #plt.figure()
    #plt.imshow(average,vmax = vmax)
    #plt.colorbar()
    del dataset
# Out:
# pos1\dty_179_counts.dat
# pos2\dty_222_counts.dat
# pos3\dty_265_counts.dat
# pos4\dty_308_counts.dat
# pos5\dty_351_counts.dat

# %%
newBadPixels = (gainArray == -1) & (mask == 0)
#newBadPixels = np.array([*newBadPixels])
plt.figure()
plt.imshow(newBadPixels)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
newBadPixelImage = fabio.edfimage.EdfImage(np.where(newBadPixels, 1, 0))
newBadPixelImage.save('newBadPixels_gainMap.edf')

# %%
newBadPixels[0,2]
# Out:
# False

# %%
newBadPixelsList = []
for y in range(len(newBadPixels)):
    for x in range(len(newBadPixels[0])):
        if newBadPixels[y,x]:
            newBadPixelsList.append([x,y])
print(newBadPixelsList)
# Out:
# [[556, 8], [19, 60], [242, 194], [244, 194], [486, 194], [494, 194], [736, 194], [738, 194], [980, 194], [1230, 194], [1232, 194], [242, 212], [244, 212], [494, 212], [736, 212], [738, 212], [980, 212], [988, 212], [1230, 212], [1232, 212], [242, 406], [244, 406], [486, 406], [494, 406], [736, 406], [738, 406], [980, 406], [988, 406], [1230, 406], [1232, 406], [242, 424], [244, 424], [486, 424], [494, 424], [736, 424], [738, 424], [980, 424], [988, 424], [1230, 424], [1232, 424], [736, 484], [736, 485], [736, 486], [512, 586], [494, 596], [242, 618], [244, 618], [486, 618], [494, 618], [736, 618], [738, 618], [980, 618], [988, 618], [1230, 618], [1232, 618], [242, 636], [244, 636], [486, 636], [494, 636], [736, 636], [738, 636], [980, 636], [988, 636], [1230, 636], [1232, 636], [562, 799], [242, 830], [244, 830], [486, 830], [494, 830], [736, 830], [738, 830], [980, 830], [988, 830], [1230, 830], [1232, 830], [242, 848], [244, 848], [486, 848], [494, 848], [736, 848], [738, 848], [98
# ...

# %%
    

plt.figure()
stdev = np.std(allDataSets[s],axis = 2)
vmax = np.percentile(np.where(np.isnan(stdev),0,stdev),99.9)
plt.imshow(np.std(allDataSets[s],axis = 2),vmax = vmax)
plt.colorbar()

# %%
len(dataset[0,1])
# Out:
# 240

# %%
#removing cosmics
# %matplotlib inline
nstdevs = 5
allDataSets2 = {}
for s in subdirs:
    

    dataset2 = np.empty(shape = allDataSets[s].shape, dtype = np.float32)
    stdev = np.nanstd(allDataSets[s],axis = 2,dtype = np.float32)
    median = np.nanmedian(allDataSets[s],axis = 2)
    for c in range(len(allDataSets[s][0,0])):
        print(s,c)
        array = allDataSets[s][:,:,c]
        
        dataset2[:,:,c] = np.where(array > median+nstdevs*stdev,np.nan,array)
        
    allDataSets2[s] = dataset2
    del dataset2
    del stdev
    del median
# Out:
# pos1 0
# pos1 1
# pos1 2
# pos1 3
# pos1 4
# pos1 5
# pos1 6
# pos1 7
# pos1 8
# pos1 9
# pos1 10
# pos1 11
# pos1 12
# pos1 13
# pos1 14
# pos1 15
# pos1 16
# pos1 17
# pos1 18
# pos1 19
# pos1 20
# pos1 21
# pos1 22
# pos1 23
# pos1 24
# pos1 25
# pos1 26
# pos1 27
# pos1 28
# pos1 29
# pos1 30
# pos1 31
# pos1 32
# pos1 33
# pos1 34
# pos1 35
# pos1 36
# pos1 37
# pos1 38
# pos1 39
# pos1 40
# pos1 41
# pos1 42
# pos1 43
# pos1 44
# pos1 45
# pos1 46
# pos1 47
# pos1 48
# pos1 49
# pos1 50
# pos1 51
# pos1 52
# pos1 53
# pos1 54
# pos1 55
# pos1 56
# pos1 57
# pos1 58
# pos1 59
# pos1 60
# pos1 61
# pos1 62
# pos1 63
# pos1 64
# pos1 65
# pos1 66
# pos1 67
# pos1 68
# pos1 69
# pos1 70
# pos1 71
# pos1 72
# pos1 73
# pos1 74
# pos1 75
# pos1 76
# pos1 77
# pos1 78
# pos1 79
# pos1 80
# pos1 81
# pos1 82
# pos1 83
# pos1 84
# pos1 85
# pos1 86
# pos1 87
# pos1 88
# pos1 89
# pos1 90
# pos1 91
# pos1 92
# pos1 93
# pos1 94
# pos1 95
# pos1 96
# pos1 97
# pos1 98
# pos1 99
# ...

# %%
allDataSets2[s].shape

# %%
stdevs = np.empty(shape = (*i1.shape,len(subdirs)))
poissonArray = np.empty(shape = (*i1.shape,len(subdirs)))
for c,s in enumerate(subdirs):
    data = allDataSets2[s]
    stdev = np.nanstd(data,axis = 2)
    stdevs[:,:,c] = stdev
    average = np.nanmean(data,axis = 2)
    poissonArray[:,:,c] = stdev**2/average
medianPoisson = np.median(poissonArray,axis=2)
# Out:
# C:\Users\kenneth1a\AppData\Local\Temp\ipykernel_13876\2290208040.py:8: RuntimeWarning: invalid value encountered in divide
#   poissonArray[:,:,c] = stdev**2/average

# %%
fimage = fabio.edfimage.EdfImage(data = medianPoisson)
fimage.save('pixelPoissonness.edf')

# %%
medianPoisson = np.nanmedian(poissonArray,axis=2)
medianPoisson = np.where(np.isnan(medianPoisson),-1,medianPoisson)
# %matplotlib nbagg
plt.figure()
plt.imshow(medianPoisson,vmin = 0.5, vmax = 1.5)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
nonPoissonArray = (medianPoisson > 1.25) | (medianPoisson < 0.75)
nonPoissonArray = np.where(nonPoissonArray, 1, 0)
nonPoissonImage = fabio.edfimage.EdfImage(nonPoissonArray)
nonPoissonImage.save('nonPoisson.edf')
plt.figure()
plt.imshow(nonPoissonArray)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
# %matplotlib inline
hist = np.histogram(np.where(medianPoisson>2,2.1,medianPoisson), bins = 100,range = (-0.1,2.1))
plt.figure()
plt.bar(hist[1][:-1],hist[0],width = 0.01)
plt.xlabel('$\sigma^2$/mean')
plt.ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
noPixels = 0
noFlaggedPixels = 0
for c,h in enumerate(hist[1]):
    if h >= 0.75 and h <= 1.25:
        noPixels += hist[0][c]
    if h < 0:
        noFlaggedPixels += hist[0][c]
print(noPixels, noFlaggedPixels)
modulePixels = 202045
chipPixels = 
1475*1679 - noPixels- modulePixels
# Out:
# 2155251 202971
# 119229

# %%
hist[1]
# Out:
# array([-0.1  , -0.079, -0.058, -0.037, -0.016,  0.005,  0.026,  0.047,
#         0.068,  0.089,  0.11 ,  0.131,  0.152,  0.173,  0.194,  0.215,
#         0.236,  0.257,  0.278,  0.299,  0.32 ,  0.341,  0.362,  0.383,
#         0.404,  0.425,  0.446,  0.467,  0.488,  0.509,  0.53 ,  0.551,
#         0.572,  0.593,  0.614,  0.635,  0.656,  0.677,  0.698,  0.719,
#         0.74 ,  0.761,  0.782,  0.803,  0.824,  0.845,  0.866,  0.887,
#         0.908,  0.929,  0.95 ,  0.971,  0.992,  1.013,  1.034,  1.055,
#         1.076,  1.097,  1.118,  1.139,  1.16 ,  1.181,  1.202,  1.223,
#         1.244,  1.265,  1.286,  1.307,  1.328,  1.349,  1.37 ,  1.391,
#         1.412,  1.433,  1.454,  1.475,  1.496,  1.517,  1.538,  1.559,
#         1.58 ,  1.601,  1.622,  1.643,  1.664,  1.685,  1.706,  1.727,
#         1.748,  1.769,  1.79 ,  1.811,  1.832,  1.853,  1.874,  1.895,
#         1.916,  1.937,  1.958,  1.979,  2.   ])

# %%
nonPoisson = []
for y in range(len(medianPoisson)):
    for x in range(len(medianPoisson[0])):
        if medianPoisson[y,x] > 1.3:
            nonPoisson.append([x,y])
print(nonPoisson)
# Out:
# [[1230, 0], [218, 1], [1230, 1], [217, 3], [399, 6], [239, 10], [1038, 11], [151, 13], [756, 33], [660, 36], [114, 39], [112, 45], [1325, 49], [1021, 52], [19, 57], [21, 57], [18, 58], [19, 58], [22, 58], [18, 59], [23, 59], [19, 60], [22, 60], [18, 61], [19, 61], [21, 61], [21, 62], [18, 63], [1294, 63], [1165, 69], [56, 70], [320, 72], [681, 84], [787, 85], [788, 86], [1360, 92], [1133, 113], [1182, 117], [1194, 123], [1002, 129], [1363, 148], [370, 151], [1019, 154], [1463, 156], [1465, 156], [404, 163], [1290, 166], [63, 175], [1036, 175], [1311, 176], [666, 177], [1081, 177], [91, 186], [988, 192], [485, 212], [486, 213], [759, 214], [1065, 214], [759, 215], [1375, 230], [436, 243], [225, 251], [1230, 256], [1337, 259], [734, 271], [1123, 272], [381, 279], [382, 279], [974, 290], [975, 290], [866, 301], [642, 314], [485, 318], [1187, 331], [1227, 337], [297, 354], [1166, 361], [1229, 361], [1121, 362], [1122, 362], [1120, 363], [1123, 363], [1120, 364], [1124, 364], [1121, 365],
# ...

# %%
plt.figure()
plt.imshow(allDataSets['pos2'][:,:,1])
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
np.max(allDataSets['pos5'][:,:,0])
# Out:
# 27443.997942653557

# %%
plt.figure()
plt.imshow(allDataSets2['pos1'][:,:,0],vmin = 0, vmax = 1e6)

# %% [markdown]
# # Loading already processed data

# %%
os.chdir(r'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap/')
gainUnfiltered = r'C:\Users\kenneth1a\Documents\beamlineData\Feb2023_gainMap\glass2\minMask/calculatedGainMap_48p6keV_unfiltered_2023-02-21.tif'
gainMap = fabio.open(gainUnfiltered).data
gainStdev = np.nanstd(np.where(gainMap == 0, np.nan, gainMap))
gainMean = np.nanmean(np.where(gainMap == 0, np.nan, gainMap))
gainMedian = np.nanmedian(np.where(gainMap == 0, np.nan, gainMap))
gainMean,gainMedian,gainStdev
# Out:
# (1.0133309, 0.9996514, 0.043661743)

# %%
# %matplotlib nbagg
poissonMap = fabio.open('glass2/pixelPoissonness.edf').data
poisson1p5 = (poissonMap > 1.5) | (poissonMap < 0.75)
chipEdges1 = (poissonMap > 0.15) & (poissonMap < 0.45 )
chipEdges2 = (poissonMap > 0.45) & (poissonMap < 0.75 )
plt.figure()
plt.imshow(gainMap,vmin = 0.9,vmax = 1.1)
plt.figure()
plt.imshow(poisson1p5)
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
# %matplotlib nbagg
histGain = np.histogram(np.where(gainMap>2,2.1,gainMap), bins = 100,range = (-0.1,2.1))
plt.figure(dpi = 150)
plt.bar(histGain[1][:-1],histGain[0],width = 0.01,log = True)
plt.xlabel('gain')
plt.ylabel('frequency')

hist = np.histogram(np.where(poissonMap>2,2.1,poissonMap), bins = 100,range = (-0.1,2.1))
plt.figure()
plt.bar(hist[1][:-1],hist[0],width = 0.01,log = False)
plt.xlabel('$\sigma^2$/mean')
plt.ylabel('frequency')
# Out:
# <img src="data:image/png;base64,..." width="960.0000254313157">
# <img src="data:image/png;base64,..." width="640.0000169542105">
# Text(0, 0.5, 'frequency')

# %%
maskLims = [1.2,1.25,1.3,1.5,1.75,2]
for n in maskLims:
    poissonMask = (poissonMap < 0.75) | (poissonMap > n)
    poissonMask = np.where(poissonMask, 1, 0)
    #nstring = str(round(n,2)).replace('.','p')
    filename = f'poissonMask_{n:.2f}'.replace('.','p') + '.edf'
    image = fabio.edfimage.EdfImage(poissonMask)
    image.save(filename)

# %%
baseMask = 'dtx0_dtr15_baseMask_lines.edf'
bm = fabio.open(baseMask).data
poissonMasks = glob('poissonMask*.edf')
poissonMasks.insert(0,baseMask)
maskDct = {}
for m in poissonMasks:
    mask = fabio.open(m).data
    mask = np.where(bm == 1, 1, mask)
    maskDct[m] = mask
    plt.figure()
    plt.imshow(mask)

# %%
poissonMasks
# Out:
# ['dtx0_dtr15_baseMask_lines.edf',
#  'poissonMask_1p20.edf',
#  'poissonMask_1p25.edf',
#  'poissonMask_1p30.edf',
#  'poissonMask_1p50.edf',
#  'poissonMask_1p75.edf',
#  'poissonMask_2p00.edf']

# %%
import pyFAI
def clearPyFAI_header(file):
    x,y,e = np.loadtxt(file,unpack = True, comments = '#')
    np.savetxt(file,np.array([x,y,e]).transpose(), '%.6f')
imageFile = r'C:\Users\kenneth1a\Documents\beamlineData\a311189_pdf\01_RbCuF3_Q0p5\pdf\xrd\average/average_gainCorrected.cbf'
poniname = r'C:\Users\kenneth1a\Documents\beamlineData\a311189_pdf/Si_0_15tilt.poni'
poni = pyFAI.load(poniname)
array = fabio.open(imageFile).data
for m in maskDct:
    mask = maskDct[m]
    maskname = m.replace('.edf','')
    outfile = f'maskData/RbCuF3_{maskname}.xye'
    outfile_2d = outfile.replace('.xye','.edf')
    x,y,e = poni.integrate1d(data = array, filename = outfile,mask = mask,polarization_factor = 0.99,unit = '2th_deg',
                correctSolidAngle = True, method = 'bbox',npt = 5000, error_model = 'poisson', safe = False)
    poni.integrate2d(data = array, filename = outfile_2d,mask = mask,polarization_factor = 0.99,unit = '2th_deg',
                correctSolidAngle = True, method = 'bbox',npt_rad = 5000,npt_azim = 360, error_model = 'poisson', safe = False)
    clearPyFAI_header(outfile)
    qy = y*4*np.pi*np.sin(x*np.pi/360)/0.25509
    outfileq = outfile.replace('.xye','_q.xye')
    np.savetxt(outfileq,np.array([x,qy,e]).transpose())
# Out:
# WARNING:fabio.cbfimage:Defaulting type to int32
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_dtx0_dtr15_baseMask_lines.xye exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_dtx0_dtr15_baseMask_lines.edf exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p20.xye exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p20.edf exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p25.xye exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p25.edf exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p30.xye exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p30.edf exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p50.xye exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p50.edf exists
# WARNING:pyFAI.io:Destination file maskData/RbCuF3_poissonMask_1p75.xye exists
# ...

# %%
help(pyFAI.geometry)
# Out:
# Help on module pyFAI.geometry in pyFAI:
#
# NAME
#     pyFAI.geometry - This modules contains only one (large) class in charge of:
#
# DESCRIPTION
#     * calculating the geometry, i.e. the position in the detector space of each pixel of the detector
#     * manages caches to store intermediate results
#
#     NOTA: The Geometry class is not a "transformation class" which would take a
#     detector and transform it. It is rather a description of the experimental setup.
#
# CLASSES
#     builtins.object
#         Geometry
#     builtins.tuple(builtins.object)
#         PolarizationArray
#         PolarizationDescription
#
#     class Geometry(builtins.object)
#      |  Geometry(dist=1, poni1=0, poni2=0, rot1=0, rot2=0, rot3=0, pixel1=None, pixel2=None, splineFile=None, detector=None, wavelength=None)
#      |
#      |  This class is the parent-class of azimuthal integrator.
#      |
#      |  This class contains a detector (using composition) which provides the
# ...

# %%
geometry = pyFAI.geometry.Geometry(detector = 'pilatus2mcdte')
geometry.load(poniname)
geometry.polarization(factor = 0.99)
# Out:
# array([[0.84199995, 0.8423464 , 0.8426926 , ..., 0.8510831 , 0.85074097,
#         0.85039854],
#        [0.84188426, 0.8422309 , 0.8425774 , ..., 0.850973  , 0.85063064,
#         0.850288  ],
#        [0.8417685 , 0.8421154 , 0.84246206, ..., 0.8508628 , 0.8505202 ,
#         0.85017735],
#        ...,
#        [0.69377184, 0.6943371 , 0.6949026 , ..., 0.70833933, 0.70776826,
#         0.70719725],
#        [0.6938735 , 0.6944387 , 0.6950041 , ..., 0.7084386 , 0.7078676 ,
#         0.7072967 ],
#        [0.6939755 , 0.69454056, 0.69510585, ..., 0.70853806, 0.7079672 ,
#         0.70739645]], dtype=float32)

# %%
twothetamap = geometry.twoThetaArray()
polarmap = geometry.polarization(factor = 0.99)
ttm_image = fabio.edfimage.EdfImage(twothetamap)
pm_image = fabio.edfimage.EdfImage(polarmap)
ttm_image.save('twothetamap_pyfai.edf')
pm_image.save('polarmap_pyfai.edf')
plt.figure()
plt.imshow(twothetamap)
plt.figure()
plt.imshow(polarmap)
